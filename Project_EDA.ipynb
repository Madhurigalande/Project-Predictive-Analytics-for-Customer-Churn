# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/Customer_Churn.csv')

# %%
df.isna().sum()
# Out:
# RowNumber             0
# CustomerId            0
# Surname               0
# CreditScore        2000
# Geography          2000
# Gender             2000
# Age                2000
# Tenure             2000
# Balance            2000
# NumOfProducts      2000
# HasCrCard          2000
# IsActiveMember     2000
# EstimatedSalary    2000
# Exited             2000
# dtype: int64

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave          NaN    France  Female  42.0
# 1          2    15647311      Hill        608.0       NaN  Female  41.0
# 2          3    15619304      Onio        502.0    France     NaN   NaN
# 3          4    15701354      Boni          NaN       NaN  Female   NaN
# 4          5    15737888  Mitchell        850.0     Spain  Female  43.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0        NaN            1.0        1.0             1.0
# 1     1.0        NaN            1.0        0.0             1.0
# 2     8.0  159660.80            NaN        1.0             0.0
# 3     1.0       0.00            2.0        0.0             0.0
# 4     NaN  125510.82            1.0        1.0             1.0
#
#    EstimatedSalary  Exited
# 0        101348.88     1.0
# 1        112542.58     0.0
# 2        113931.57     NaN
# 3         93826.63     0.0
# 4              NaN     0.0

# %%
df.size
# Out:
# 1540000

# %%
df.shape
# Out:
# (110000, 14)

# %%
df.isna().sum()
# Out:
# RowNumber             0
# CustomerId            0
# Surname               0
# CreditScore        2000
# Geography          2000
# Gender             2000
# Age                2000
# Tenure             2000
# Balance            2000
# NumOfProducts      2000
# HasCrCard          2000
# IsActiveMember     2000
# EstimatedSalary    2000
# Exited             2000
# dtype: int64

# %%
for column in df.columns:
    null_count = df[column].isnull().sum()
    print(f"Column: {column} --> Null values: {null_count}")
# Out:
# Column: RowNumber --> Null values: 0
# Column: CustomerId --> Null values: 0
# Column: Surname --> Null values: 0
# Column: CreditScore --> Null values: 2000
# Column: Geography --> Null values: 2000
# Column: Gender --> Null values: 2000
# Column: Age --> Null values: 2000
# Column: Tenure --> Null values: 2000
# Column: Balance --> Null values: 2000
# Column: NumOfProducts --> Null values: 2000
# Column: HasCrCard --> Null values: 2000
# Column: IsActiveMember --> Null values: 2000
# Column: EstimatedSalary --> Null values: 2000
# Column: Exited --> Null values: 2000

# %%
df.describe()
# Out:
#            RowNumber    CustomerId    CreditScore            Age  \
# count  110000.000000  1.100000e+05  108000.000000  108000.000000
# mean     5001.502927  1.569132e+07     651.214481      38.987500
# std      2877.417392  7.179727e+04      96.376393      10.513241
# min         1.000000  1.556570e+07     350.000000      18.000000
# 25%      2514.000000  1.562924e+07     585.000000      32.000000
# 50%      5007.000000  1.569112e+07     652.000000      37.000000
# 75%      7492.000000  1.575360e+07     718.000000      44.000000
# max     10000.000000  1.581569e+07     850.000000      92.000000
#
#               Tenure        Balance  NumOfProducts      HasCrCard  \
# count  108000.000000  108000.000000  108000.000000  108000.000000
# mean        4.990630   76886.710889       1.526352       0.702352
# std         2.883132   62424.803450       0.576237       0.457226
# min         0.000000       0.000000       1.000000       0.000000
# 25%         2.000000       0.000000       1.000000       0.000000
# 50%         5.000000   97339.090000       1.000000       1.000000
# 75%         7.000000  127785.170000       2.000000       1.000000
# max        10.000000  250898.090000       4.000000       1.000000
#
#        IsActiveMember  EstimatedSalary         Exited
# count   108000.000000    108000.000000  108000.000000
# mean         0.515796    100281.274519       0.204565
# std          0.499753     57256.382428       0.403385
# min          0.000000        90.070000       0.000000
# 25%          0.000000     51907.720000       0.000000
# 50%          1.000000    100615.140000       0.000000
# 75%          1.000000    149170.920000       0.000000
# max          1.000000    199992.480000       1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110000 entries, 0 to 109999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   RowNumber        110000 non-null  int64
#  1   CustomerId       110000 non-null  int64
#  2   Surname          110000 non-null  object
#  3   CreditScore      108000 non-null  float64
#  4   Geography        108000 non-null  object
#  5   Gender           108000 non-null  object
#  6   Age              108000 non-null  float64
#  7   Tenure           108000 non-null  float64
#  8   Balance          108000 non-null  float64
#  9   NumOfProducts    108000 non-null  float64
#  10  HasCrCard        108000 non-null  float64
#  11  IsActiveMember   108000 non-null  float64
#  12  EstimatedSalary  108000 non-null  float64
#  13  Exited           108000 non-null  float64
# dtypes: float64(9), int64(2), object(3)
# memory usage: 11.7+ MB

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave          NaN    France  Female  42.0
# 1          2    15647311      Hill        608.0       NaN  Female  41.0
# 2          3    15619304      Onio        502.0    France     NaN   NaN
# 3          4    15701354      Boni          NaN       NaN  Female   NaN
# 4          5    15737888  Mitchell        850.0     Spain  Female  43.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0        NaN            1.0        1.0             1.0
# 1     1.0        NaN            1.0        0.0             1.0
# 2     8.0  159660.80            NaN        1.0             0.0
# 3     1.0       0.00            2.0        0.0             0.0
# 4     NaN  125510.82            1.0        1.0             1.0
#
#    EstimatedSalary  Exited
# 0        101348.88     1.0
# 1        112542.58     0.0
# 2        113931.57     NaN
# 3         93826.63     0.0
# 4              NaN     0.0

# %%
median_value = df['CreditScore'].median()
df['CreditScore'].fillna(median_value, inplace=True)
# Out:
# /tmp/ipython-input-92-1436268040.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['CreditScore'].fillna(median_value, inplace=True)

# %%
mode_value = df['Geography'].mode()[0]
df['Geography'].fillna(mode_value, inplace=True)
# Out:
# /tmp/ipython-input-93-4096277024.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Geography'].fillna(mode_value, inplace=True)

# %%
mode_value = df['Gender'].mode()[0]
df['Gender'].fillna(mode_value, inplace=True)
# Out:
# /tmp/ipython-input-94-2235347816.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna(mode_value, inplace=True)

# %%
median_value = df['Age'].median()
df['Age'].fillna(median_value, inplace=True)
# Out:
# /tmp/ipython-input-95-1259839543.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(median_value, inplace=True)

# %%
df['Tenure'].fillna(0, inplace=True)
# Out:
# /tmp/ipython-input-96-30182584.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Tenure'].fillna(0, inplace=True)

# %%
df['Balance'].fillna(0, inplace=True)
# Out:
# /tmp/ipython-input-97-1905434942.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Balance'].fillna(0, inplace=True)

# %%
mode_value = df['NumOfProducts'].mode()[0]
df['NumOfProducts'].fillna(mode_value, inplace=True)
# Out:
# /tmp/ipython-input-98-1893646561.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['NumOfProducts'].fillna(mode_value, inplace=True)

# %%
mode_value = df['HasCrCard'].mode()[0]
df['HasCrCard'].fillna(mode_value, inplace=True)
# Out:
# /tmp/ipython-input-99-1244580646.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['HasCrCard'].fillna(mode_value, inplace=True)

# %%
df['IsActiveMember'].fillna(0, inplace=True)
# Out:
# /tmp/ipython-input-100-3034994030.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['IsActiveMember'].fillna(0, inplace=True)

# %%
df['EstimatedSalary'].fillna(0, inplace=True)
# Out:
# /tmp/ipython-input-101-224662522.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['EstimatedSalary'].fillna(0, inplace=True)

# %%
df = df.dropna(subset=['Exited'])

# %%
df.size
# Out:
# 1512000

# %%
df.shape
# Out:
# (108000, 14)

# %%
df['Exited'] = df['Exited'].astype(int)
df['IsActiveMember'] = df['IsActiveMember'].astype(int)
df['HasCrCard'] = df['HasCrCard'].astype(int)
df['NumOfProducts'] = df['NumOfProducts'].astype(int)

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave        652.0    France  Female  42.0
# 1          2    15647311      Hill        608.0    France  Female  41.0
# 3          4    15701354      Boni        652.0    France  Female  37.0
# 4          5    15737888  Mitchell        850.0     Spain  Female  43.0
# 5          6    15574012       Chu        645.0     Spain    Male  44.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0       0.00              1          1               1
# 1     1.0       0.00              1          0               1
# 3     1.0       0.00              2          0               0
# 4     0.0  125510.82              1          1               1
# 5     8.0  113755.78              2          1               0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 3         93826.63       0
# 4             0.00       0
# 5        149756.71       1

# %% [markdown]
# # EDA

# %%
df.to_csv('churning_clean.csv', index=False)

# %%
df['Exited'].value_counts()
# Out:
# Exited
# 0    85907
# 1    22093
# Name: count, dtype: int64

# %%
plt.bar(df['Exited'].value_counts().index, df['Exited'].value_counts())
plt.xlabel('Exited Status')
plt.ylabel('Count')
plt.title('Customer Exit Distribution')
plt.show()

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave        652.0    France  Female  42.0
# 1          2    15647311      Hill        608.0    France  Female  41.0
# 3          4    15701354      Boni        652.0    France  Female  37.0
# 4          5    15737888  Mitchell        850.0     Spain  Female  43.0
# 5          6    15574012       Chu        645.0     Spain    Male  44.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0       0.00              1          1               1
# 1     1.0       0.00              1          0               1
# 3     1.0       0.00              2          0               0
# 4     0.0  125510.82              1          1               1
# 5     8.0  113755.78              2          1               0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 3         93826.63       0
# 4             0.00       0
# 5        149756.71       1

# %%
plt.bar(df['Gender'].value_counts().index, df['Gender'].value_counts())
plt.xlabel('Gender')
plt.ylabel('Gender')
plt.title('Gender')
plt.show()

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      59852
# Female    48148
# Name: count, dtype: int64

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     54373
# Germany    27050
# Spain      26577
# Name: count, dtype: int64

# %%
plt.bar(df['Geography'].value_counts().index, df['Geography'].value_counts())
plt.xlabel('Geography')
plt.ylabel('Geography')
plt.title('Geography')
plt.show()

# %%
plt.figure(figsize=(8, 6))sns.boxplot(x=df['Gender'], y=df['EstimatedSalary'], data=df, palette='Set2')

plt.title('Boxplot of Salary by Gender')
plt.xlabel('Gender')
plt.ylabel('Salary')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np


numerical_columns = df.select_dtypes(include=[np.number]).columns


cols = 3
rows = int(np.ceil(len(numerical_columns) / cols))


fig, ax = plt.subplots(rows, cols, figsize=(15, 5 * rows))
ax = ax.flatten()


for index, col in enumerate(numerical_columns):
    sns.histplot(df[col], kde=True, ax=ax[index])
    ax[index].set_title(f'Distribution of {col}')


for j in range(index + 1, len(ax)):
    fig.delaxes(ax[j])

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 8))
plt.xticks(rotation=90)
sns.barplot(x='HasCrCard',y='Geography',hue='Gender',data=df);

# %%
plt.figure(figsize=(15, 8))
plt.xticks(rotation=90)
sns.barplot(x='HasCrCard',y='Exited',hue='Gender',data=df);

# %%
plt.figure(figsize=(15, 8))
plt.xticks(rotation=90)
sns.barplot(x='IsActiveMember',y='EstimatedSalary',hue='Gender',data=df);

# %%
plt.figure(figsize=(15, 8))
plt.xticks(rotation=90)
sns.barplot(x='IsActiveMember',y='Exited',hue='Gender',data=df);

# %%
plt.figure(figsize=(15, 8))
plt.xticks(rotation=90)
sns.barplot(x='IsActiveMember',y='Geography',hue='Gender',data=df);

# %%
plt.figure(figsize=(15, 8))
plt.xticks(rotation=90)
sns.barplot(x='Age',y='Tenure',hue='Gender',data=df);

# %%
plt.figure(figsize=(15, 8))
plt.xticks(rotation=90)
sns.barplot(x='NumOfProducts',y='EstimatedSalary',data=df);

# %%
plt.figure(figsize=(15, 8))
plt.xticks(rotation=90)
sns.barplot(x='Age',y='Exited',color='teal',data=df);
